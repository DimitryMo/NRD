# %% [markdown]
# <a href="https://colab.research.google.com/github/DimitryMo/NSD/blob/master/Untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
import nltk
#nltk.download()

# %%
import sys
import csv
csv.field_size_limit(sys.maxsize)
# Out:
# 131072

# %%
data = pd.read_csv("allhabr.csv", delimiter=',', engine='python', encoding='utf-8', error_bad_lines=False)

# %%
data.head()
# Out:
#    Unnamed: 0                                              title  \
# 0           0  Психологическая обусловленность возникновения ...
# 1           1        Обзор трафарет+блокнот для прототипирования
# 2           2            Хранилище данных уровня SOHO из картона
# 3           3          Год большого рывка: краткие итоги 2013-го
# 4           4                6 простых вопросов по C# с подвохом
#
#                                                 text     date  \
# 0  Видимо  вспышки на солнце  в том числе  послуж...  2014-01
# 1  Некоторое время были у меня в руках предметы  ...  2014-01
# 2    Потребность в хранилище данных у меня возник...  2014-01
# 3         год был годом новых базовых станций и н...  2014-01
# 4  Почитав    простых задач на c  с подвохом я ог...  2014-01
#
#                                                 hubs  \
# 0                             Разработка веб-сайтов
# 1                                        Интерфейсы
# 2                                DIY или Сделай сам
# 3  Блог компании ВымпелКом (Билайн) Разработка си...
# 4                                              .NET
#
#                                                 tags  votes    views  \
# 0  Web 3.0 психология социальные сети носимая эле...   -3.0   6600.0
# 1  prototype прототип prototyping прототипировани...   35.0  38400.0
# 2  diy или сделай сам хранение данных хранилище д...  -11.0  13700.0
# 3    Сотовая связь сервис LTE Билайн Вымпелком 2013    20.0  14000.0
# 4  c# .net внезапно не делайте так никогда кровь ...   37.0  35800.0
#
#    bookmarks                                           comments
# 0       10.0  Думаю, всем нам известно, что это будут за час...
# 1      124.0  Где можно такой заказать?~#www.uistencils.com/...
# 2       12.0  Тему переименовать — Как собрать скворечник.\n...
# 3       19.0  В москве и области функционал дозвона в режиме...
# 4      204.0  «Можно ли в C# „поковырять“ память, которую вы...

# %%
data.shape[0]
# Out:
# 49780

# %%
filik = data[0:100]

# %%
filik.dropna(inplace=True)
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
dat = filik['text'] #создаем новую колонку, в которой все слова текста в нижнем регистре представлены в форме списка

bignew=[]
for i in dat:
    new = []
    for j in i.split():
        new.append(j.lower())
    bignew.append(new)
filik['textlower'] = bignew
filik['textlower']
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   if __name__ == '__main__':
# 0     [видимо, вспышки, на, солнце, в, том, числе, п...
# 1     [некоторое, время, были, у, меня, в, руках, пр...
# 2     [потребность, в, хранилище, данных, у, меня, в...
# 3     [год, был, годом, новых, базовых, станций, и, ...
# 4     [почитав, простых, задач, на, c, с, подвохом, ...
#                             ...
# 95    [введение, всем, доброго, времени, суток, в, с...
# 96    [хочется, напомнить, всем, кому, интересно, ра...
# 97    [технологии, в, ролевых, играх, часть, техноло...
# 98    [у, jquery, есть, встроенная, фича, если, серв...
# 99    [с, луны, несмотря, на, выходные, поступают, н...
# Name: textlower, Length: 98, dtype: object

# %%
filik['textlowerstring'] = filik['textlower'].apply(' '.join)
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
filik['textlowerstring']
# Out:
# 0     видимо вспышки на солнце в том числе послужили...
# 1     некоторое время были у меня в руках предметы и...
# 2     потребность в хранилище данных у меня возникла...
# 3     год был годом новых базовых станций и новых се...
# 4     почитав простых задач на c с подвохом я огорчи...
#                             ...
# 95    введение всем доброго времени суток в своей пе...
# 96    хочется напомнить всем кому интересно развитие...
# 97    технологии в ролевых играх часть технология и ...
# 98    у jquery есть встроенная фича если сервер отве...
# 99    с луны несмотря на выходные поступают новости ...
# Name: textlowerstring, Length: 98, dtype: object

# %%
from nltk.corpus import stopwords
import nltk
nltk.download('punkt')
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package punkt to /Users/freezylex/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/freezylex/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
from nltk.tokenize import word_tokenize

# %%
filik['texttok'] = filik.textlowerstring.apply(lambda x: word_tokenize(x))
filik['texttok']
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# 0     [видимо, вспышки, на, солнце, в, том, числе, п...
# 1     [некоторое, время, были, у, меня, в, руках, пр...
# 2     [потребность, в, хранилище, данных, у, меня, в...
# 3     [год, был, годом, новых, базовых, станций, и, ...
# 4     [почитав, простых, задач, на, c, с, подвохом, ...
#                             ...
# 95    [введение, всем, доброго, времени, суток, в, с...
# 96    [хочется, напомнить, всем, кому, интересно, ра...
# 97    [технологии, в, ролевых, играх, часть, техноло...
# 98    [у, jquery, есть, встроенная, фича, если, серв...
# 99    [с, луны, несмотря, на, выходные, поступают, н...
# Name: texttok, Length: 98, dtype: object

# %%
nomorebadwords = []
from nltk.corpus import stopwords
stop_words = set(stopwords.words("russian"))
for j in filik['texttok']:
    smallbw = []
    for i in j:
        if i not in stop_words:
            smallbw.append(i)
    nomorebadwords.append(smallbw)
filik['textalmostdone'] = nomorebadwords
filik['textalmostdone']
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # Remove the CWD from sys.path while we load stuff.
# 0     [видимо, вспышки, солнце, числе, послужили, пр...
# 1     [некоторое, время, руках, предметы, интересные...
# 2     [потребность, хранилище, данных, возникла, дов...
# 3     [год, годом, новых, базовых, станций, новых, с...
# 4     [почитав, простых, задач, c, подвохом, огорчил...
#                             ...
# 95    [введение, всем, доброго, времени, суток, свое...
# 96    [хочется, напомнить, всем, кому, интересно, ра...
# 97    [технологии, ролевых, играх, часть, технология...
# 98    [jquery, встроенная, фича, сервер, ответит, co...
# 99    [луны, несмотря, выходные, поступают, новости,...
# Name: textalmostdone, Length: 98, dtype: object

# %%
import pymorphy2
morph = pymorphy2.MorphAnalyzer()

# %%
def lemmatize(text):    #приводим в исходную форму слово
    res = list()
    for line in text:
        res1 = list()
        for word in line:
            p = morph.parse(word)[0]
            res1.append(p.normal_form)
        res.append(res1)

    return res

filik['done'] = lemmatize(filik['textalmostdone'])
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   if sys.path[0] == '':

# %%
filik['done']
# Out:
# 0     [видимо, вспышка, солнце, число, послужить, пр...
# 1     [некоторый, время, рука, предмет, интересный, ...
# 2     [потребность, хранилище, дать, возникнуть, дов...
# 3     [год, год, новый, базовый, станция, новый, сер...
# 4     [почитать, простой, задача, c, подвох, огорчит...
#                             ...
# 95    [введение, весь, добрый, время, сутки, свой, о...
# 96    [хотеться, напомнить, весь, кома, интересно, р...
# 97    [технология, ролевый, игра, часть, технология,...
# 98    [jquery, встроить, фич, сервер, ответить, cont...
# 99    [луна, несмотря, выходной, поступать, новость,...
# Name: done, Length: 98, dtype: object

# %%
from gensim.corpora.dictionary import Dictionary

# %%
dictionary = Dictionary(filik['done'])

# %%
corpus = [dictionary.doc2bow(article) for article in filik['done']]

# %%
import collections
import itertools

total_word_count = collections.defaultdict(int)
for word_id, word_count in itertools.chain.from_iterable(corpus):
    total_word_count[word_id] += word_count

# %%
import collections
import itertools
l = []
for doc in corpus:
    bow_doc = sorted(doc, key=lambda w: w[1], reverse=True)
    l1 = []
    for word_id, word_count in bow_doc:
        l1.append((dictionary.get(word_id), word_count))
    l.append(l1)
filik['countwords'] = l
filik
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # Remove the CWD from sys.path while we load stuff.
#     Unnamed: 0                                              title  \
# 0            0  Психологическая обусловленность возникновения ...
# 1            1        Обзор трафарет+блокнот для прототипирования
# 2            2            Хранилище данных уровня SOHO из картона
# 3            3          Год большого рывка: краткие итоги 2013-го
# 4            4                6 простых вопросов по C# с подвохом
# ..         ...                                                ...
# 95          95  Зашифрованное взаимодействие между клиентом и ...
# 96          96                   Начинаются курсы «Универсариума»
# 97          97  Технологии в ролевых играх. Часть 3. Технологи...
# 98          98                   Почему не нужно использовать RJS
# 99          99  Панорама Луны от «Чанъе 3» и выход из строя гл...
#
#                                                  text     date  \
# 0   Видимо  вспышки на солнце  в том числе  послуж...  2014-01
# 1   Некоторое время были у меня в руках предметы  ...  2014-01
# 2     Потребность в хранилище данных у меня возник...  2014-01
# 3          год был годом новых базовых станций и н...  2014-01
# 4   Почитав    простых задач на c  с подвохом я ог...  2014-01
# ..                                                ...      ...
# 95  Введение Всем доброго времени суток  В своей п...  2014-01
# 96  Хочется напомнить всем  кому интересно развити...  2014-01
# 97  Технологии в ролевых играх  Часть    Технологи...  2014-01
# 98  У jQuery есть встроенная фича   если сервер от...  2014-01
# 99    С Луны  несмотря на выходные  поступают ново...  2014-01
#
#                                                  hubs  \
# 0                              Разработка веб-сайтов
# 1                                         Интерфейсы
# 2                                 DIY или Сделай сам
# 3   Блог компании ВымпелКом (Билайн) Разработка си...
# 4                                               .NET
# ..                                                ...
# 95        Разработка веб-сайтов Криптография Laravel
# 96                                         Я пиарюсь
# 97                                    Разработка игр
# 98  Информационная безопасность Разработка веб-сай...
# 99                                      Космонавтика
#
#                                                  tags  votes    views  \
# 0   Web 3.0 психология социальные сети носимая эле...   -3.0   6600.0
# 1   prototype прототип prototyping прототипировани...   35.0  38400.0
# 2   diy или сделай сам хранение данных хранилище д...  -11.0  13700.0
# 3     Сотовая связь сервис LTE Билайн Вымпелком 2013    20.0  14000.0
# 4   c# .net внезапно не делайте так никогда кровь ...   37.0  35800.0
# ..                                                ...    ...      ...
# 95    laravel шифрование данных rsa aes solid дизайн    12.0  16200.0
# 96         mooc e-learning online-обучение education    24.0   5500.0
# 97           ролевые игры технологии магия киберпанк    40.0  29600.0
# 98                                         rails rjs    24.0  12000.0
# 99                    луна космос луноход юйту Чанъе    35.0  39300.0
#
#     bookmarks                                           comments  \
# 0        10.0  Думаю, всем нам известно, что это будут за час...
# 1       124.0  Где можно такой заказать?~#www.uistencils.com/...
# 2        12.0  Тему переименовать — Как собрать скворечник.\n...
# 3        19.0  В москве и области функционал дозвона в режиме...
# 4       204.0  «Можно ли в C# „поковырять“ память, которую вы...
# ..        ...                                                ...
# 95       83.0  Все существующие алгоритмы шифрования можно ра...
# 96       62.0  Пока бродил по Вашему сайту наткнулся на дохлы...
# 97      110.0  Девушку случайно не Настя зовут на иллюстрации...
# 98       48.0  Про какое исправление в какой конкретно новой ...
# 99       18.0  А вот фотография лунного грунта, сделанная ком...
#
#                                             textlower  \
# 0   [видимо, вспышки, на, солнце, в, том, числе, п...
# 1   [некоторое, время, были, у, меня, в, руках, пр...
# 2   [потребность, в, хранилище, данных, у, меня, в...
# 3   [год, был, годом, новых, базовых, станций, и, ...
# 4   [почитав, простых, задач, на, c, с, подвохом, ...
# ..                                                ...
# 95  [введение, всем, доброго, времени, суток, в, с...
# 96  [хочется, напомнить, всем, кому, интересно, ра...
# 97  [технологии, в, ролевых, играх, часть, техноло...
# 98  [у, jquery, есть, встроенная, фича, если, серв...
# 99  [с, луны, несмотря, на, выходные, поступают, н...
#
#                                       textlowerstring  \
# 0   видимо вспышки на солнце в том числе послужили...
# 1   некоторое время были у меня в руках предметы и...
# 2   потребность в хранилище данных у меня возникла...
# 3   год был годом новых базовых станций и новых се...
# 4   почитав простых задач на c с подвохом я огорчи...
# ..                                                ...
# 95  введение всем доброго времени суток в своей пе...
# 96  хочется напомнить всем кому интересно развитие...
# 97  технологии в ролевых играх часть технология и ...
# 98  у jquery есть встроенная фича если сервер отве...
# 99  с луны несмотря на выходные поступают новости ...
#
#                                               texttok  \
# 0   [видимо, вспышки, на, солнце, в, том, числе, п...
# 1   [некоторое, время, были, у, меня, в, руках, пр...
# 2   [потребность, в, хранилище, данных, у, меня, в...
# 3   [год, был, годом, новых, базовых, станций, и, ...
# 4   [почитав, простых, задач, на, c, с, подвохом, ...
# ..                                                ...
# 95  [введение, всем, доброго, времени, суток, в, с...
# 96  [хочется, напомнить, всем, кому, интересно, ра...
# 97  [технологии, в, ролевых, играх, часть, техноло...
# 98  [у, jquery, есть, встроенная, фича, если, серв...
# 99  [с, луны, несмотря, на, выходные, поступают, н...
#
#                                        textalmostdone  \
# 0   [видимо, вспышки, солнце, числе, послужили, пр...
# 1   [некоторое, время, руках, предметы, интересные...
# 2   [потребность, хранилище, данных, возникла, дов...
# 3   [год, годом, новых, базовых, станций, новых, с...
# 4   [почитав, простых, задач, c, подвохом, огорчил...
# ..                                                ...
# 95  [введение, всем, доброго, времени, суток, свое...
# 96  [хочется, напомнить, всем, кому, интересно, ра...
# 97  [технологии, ролевых, играх, часть, технология...
# 98  [jquery, встроенная, фича, сервер, ответит, co...
# 99  [луны, несмотря, выходные, поступают, новости,...
#
#                                                  done  \
# 0   [видимо, вспышка, солнце, число, послужить, пр...
# 1   [некоторый, время, рука, предмет, интересный, ...
# 2   [потребность, хранилище, дать, возникнуть, дов...
# 3   [год, год, новый, базовый, станция, новый, сер...
# 4   [почитать, простой, задача, c, подвох, огорчит...
# ..                                                ...
# 95  [введение, весь, добрый, время, сутки, свой, о...
# 96  [хотеться, напомнить, весь, кома, интересно, р...
# 97  [технология, ролевый, игра, часть, технология,...
# 98  [jquery, встроить, фич, сервер, ответить, cont...
# 99  [луна, несмотря, выходной, поступать, новость,...
#
#                                                 words  \
# 0   [(человек, 24), (это, 17), (потребность, 13), ...
# 1   [(трафарет, 16), (блокнот, 9), (программа, 5),...
# 2   [(хранилище, 8), (диск, 7), (довольно, 7), (сд...
# 3   [(год, 15), (сеть, 14), (большой, 6), (один, 6...
# 4   [(f, 25), (static, 23), (color, 22), (mov, 20)...
# ..                                                ...
# 95  [(this, 52), (key, 41), (app, 39), (cryptograp...
# 96  [(проект, 6), (курс, 4), (обучение, 3), (образ...
# 97  [(игрок, 17), (возможность, 11), (время, 9), (...
# 98  [(text, 6), (script, 5), (javascript, 4), (кот...
# 99  [(лунный, 5), (китайский, 4), (станция, 3), (п...
#
#                                            countwords  \
# 0   [(человек, 24), (это, 17), (потребность, 13), ...
# 1   [(трафарет, 16), (блокнот, 9), (программа, 5),...
# 2   [(хранилище, 8), (диск, 7), (довольно, 7), (сд...
# 3   [(год, 15), (сеть, 14), (большой, 6), (один, 6...
# 4   [(f, 25), (static, 23), (color, 22), (mov, 20)...
# ..                                                ...
# 95  [(this, 52), (key, 41), (app, 39), (cryptograp...
# 96  [(проект, 6), (курс, 4), (обучение, 3), (образ...
# 97  [(игрок, 17), (возможность, 11), (время, 9), (...
# 98  [(text, 6), (script, 5), (javascript, 4), (кот...
# 99  [(лунный, 5), (китайский, 4), (станция, 3), (п...
#
#                                           weightwords
# 0   [(психика, 0.2932402829605896), (потребность, ...
# 1   [(трафарет, 0.7347832979118797), (блокнот, 0.3...
# 2   [(двп, 0.3614689740294963), (хранилище, 0.3328...
# 3   [(lte, 0.3067796106915642), (абонент, 0.301181...
# 4   [(dword, 0.25567443559759884), (ebp, 0.2556744...
# ..                                                ...
# 95  [(key, 0.31434897467634015), (cryptography, 0....
# 96  [(образовательный, 0.3699055046709782), (униве...
# 97  [(игрок, 0.3602310203498023), (локация, 0.2434...
# 98  [(script, 0.4666774420445835), (text, 0.306027...
# 99  [(лунный, 0.46864452196010675), (посадочный, 0...
#
# [98 rows x 18 columns]

# %%
from gensim.models.tfidfmodel import TfidfModel

tfidf = TfidfModel(corpus)
tfidf_weights = tfidf[doc]
sorted_tfidf_weights = sorted(tfidf_weights, key=lambda w: w[1], reverse=True)
for term_id, weight in sorted_tfidf_weights[:5]:
    print(dictionary.get(term_id), weight)
# Out:
# лунный 0.46864452196010675
# посадочный 0.2811867131760641
# китайский 0.2690816187902251
# грунт 0.2208447181682414
# фотография 0.2018112140926688

# %%
L2=[]
for doc in corpus:
    l2=[]
    tfidf_weights = tfidf[doc]
    sorted_tfidf_weights = sorted(tfidf_weights, key=lambda w: w[1], reverse=True)
    for term_id, weight in sorted_tfidf_weights[:10]:
        l2.append((dictionary.get(term_id), weight))
    L2.append(l2)
filik['weightwords'] = L2
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   if __name__ == '__main__':

# %%
filik.head(6)
# Out:
#    Unnamed: 0                                              title  \
# 0           0  Психологическая обусловленность возникновения ...
# 1           1        Обзор трафарет+блокнот для прототипирования
# 2           2            Хранилище данных уровня SOHO из картона
# 3           3          Год большого рывка: краткие итоги 2013-го
# 4           4                6 простых вопросов по C# с подвохом
# 6           6  Pdef — компилятор и язык описания интерфейсов ...
#
#                                                 text     date  \
# 0  Видимо  вспышки на солнце  в том числе  послуж...  2014-01
# 1  Некоторое время были у меня в руках предметы  ...  2014-01
# 2    Потребность в хранилище данных у меня возник...  2014-01
# 3         год был годом новых базовых станций и н...  2014-01
# 4  Почитав    простых задач на c  с подвохом я ог...  2014-01
# 6  В начале прошлого года мне пришла в голову иде...  2014-01
#
#                                                 hubs  \
# 0                             Разработка веб-сайтов
# 1                                        Интерфейсы
# 2                                DIY или Сделай сам
# 3  Блог компании ВымпелКом (Билайн) Разработка си...
# 4                                              .NET
# 6            Разработка веб-сайтов Программирование
#
#                                                 tags  votes    views  \
# 0  Web 3.0 психология социальные сети носимая эле...   -3.0   6600.0
# 1  prototype прототип prototyping прототипировани...   35.0  38400.0
# 2  diy или сделай сам хранение данных хранилище д...  -11.0  13700.0
# 3    Сотовая связь сервис LTE Билайн Вымпелком 2013    20.0  14000.0
# 4  c# .net внезапно не делайте так никогда кровь ...   37.0  35800.0
# 6   pdef protobuf thrift idl python java objectivec    46.0   9600.0
#
#    bookmarks                                           comments  \
# 0       10.0  Думаю, всем нам известно, что это будут за час...
# 1      124.0  Где можно такой заказать?~#www.uistencils.com/...
# 2       12.0  Тему переименовать — Как собрать скворечник.\n...
# 3       19.0  В москве и области функционал дозвона в режиме...
# 4      204.0  «Можно ли в C# „поковырять“ память, которую вы...
# 6      130.0  Достаточно интересно с первого взгляда.\nНалич...
#
#                                            textlower  \
# 0  [видимо, вспышки, на, солнце, в, том, числе, п...
# 1  [некоторое, время, были, у, меня, в, руках, пр...
# 2  [потребность, в, хранилище, данных, у, меня, в...
# 3  [год, был, годом, новых, базовых, станций, и, ...
# 4  [почитав, простых, задач, на, c, с, подвохом, ...
# 6  [в, начале, прошлого, года, мне, пришла, в, го...
#
#                                      textlowerstring  \
# 0  видимо вспышки на солнце в том числе послужили...
# 1  некоторое время были у меня в руках предметы и...
# 2  потребность в хранилище данных у меня возникла...
# 3  год был годом новых базовых станций и новых се...
# 4  почитав простых задач на c с подвохом я огорчи...
# 6  в начале прошлого года мне пришла в голову иде...
#
#                                              texttok  \
# 0  [видимо, вспышки, на, солнце, в, том, числе, п...
# 1  [некоторое, время, были, у, меня, в, руках, пр...
# 2  [потребность, в, хранилище, данных, у, меня, в...
# 3  [год, был, годом, новых, базовых, станций, и, ...
# 4  [почитав, простых, задач, на, c, с, подвохом, ...
# 6  [в, начале, прошлого, года, мне, пришла, в, го...
#
#                                       textalmostdone  \
# 0  [видимо, вспышки, солнце, числе, послужили, пр...
# 1  [некоторое, время, руках, предметы, интересные...
# 2  [потребность, хранилище, данных, возникла, дов...
# 3  [год, годом, новых, базовых, станций, новых, с...
# 4  [почитав, простых, задач, c, подвохом, огорчил...
# 6  [начале, прошлого, года, пришла, голову, идея,...
#
#                                                 done  \
# 0  [видимо, вспышка, солнце, число, послужить, пр...
# 1  [некоторый, время, рука, предмет, интересный, ...
# 2  [потребность, хранилище, дать, возникнуть, дов...
# 3  [год, год, новый, базовый, станция, новый, сер...
# 4  [почитать, простой, задача, c, подвох, огорчит...
# 6  [начало, прошлое, год, пришлый, голова, идея, ...
#
#                                                words  \
# 0  [(человек, 24), (это, 17), (потребность, 13), ...
# 1  [(трафарет, 16), (блокнот, 9), (программа, 5),...
# 2  [(хранилище, 8), (диск, 7), (довольно, 7), (сд...
# 3  [(год, 15), (сеть, 14), (большой, 6), (один, 6...
# 4  [(f, 25), (static, 23), (color, 22), (mov, 20)...
# 6  [(тип, 32), (pdef, 27), (интерфейс, 25), (stri...
#
#                                           countwords  \
# 0  [(человек, 24), (это, 17), (потребность, 13), ...
# 1  [(трафарет, 16), (блокнот, 9), (программа, 5),...
# 2  [(хранилище, 8), (диск, 7), (довольно, 7), (сд...
# 3  [(год, 15), (сеть, 14), (большой, 6), (один, 6...
# 4  [(f, 25), (static, 23), (color, 22), (mov, 20)...
# 6  [(тип, 32), (pdef, 27), (интерфейс, 25), (stri...
#
#                                          weightwords
# 0  [(психика, 0.2932402829605896), (потребность, ...
# 1  [(трафарет, 0.7347832979118797), (блокнот, 0.3...
# 2  [(двп, 0.3614689740294963), (хранилище, 0.3328...
# 3  [(lte, 0.3067796106915642), (абонент, 0.301181...
# 4  [(dword, 0.25567443559759884), (ebp, 0.2556744...
# 6  [(pdef, 0.3292337961730401), (наследование, 0....

# %%
import re
for i in data['tags']:
    match = re.search("стартап", i)
    if match is not None:
        print(match)
# Out:
# <re.Match object; span=(0, 7), match='стартап'>
# <re.Match object; span=(0, 7), match='стартап'>
# <re.Match object; span=(23, 30), match='стартап'>
# <re.Match object; span=(7, 14), match='стартап'>
# <re.Match object; span=(27, 34), match='стартап'>
# <re.Match object; span=(0, 7), match='стартап'>
# <re.Match object; span=(37, 44), match='стартап'>
# <re.Match object; span=(17, 24), match='стартап'>
# <re.Match object; span=(37, 44), match='стартап'>
# <re.Match object; span=(0, 7), match='стартап'>
# <re.Match object; span=(20, 27), match='стартап'>
# <re.Match object; span=(43, 50), match='стартап'>
# <re.Match object; span=(7, 14), match='стартап'>
# <re.Match object; span=(11, 18), match='стартап'>
# <re.Match object; span=(0, 7), match='стартап'>
# <re.Match object; span=(0, 7), match='стартап'>
# <re.Match object; span=(0, 7), match='стартап'>
# <re.Match object; span=(12, 19), match='стартап'>
# <re.Match object; span=(11, 18), match='стартап'>
# <re.Match object; span=(0, 7), match='стартап'>
# <re.Match object; span=(0, 7), match='стартап'>
# <re.Match object; span=(55, 62), match='стартап'>
# <re.Match object; span=(132, 139), match='стартап'>
# <re.Match object; span=(20, 27), match='стартап'>
# <re.Match object; span=(108, 115), match='стартап'>
# <re.Match object; span=(48, 55), match='стартап'>
# <re.Match object; span=(8, 15), match='стартап'>
# <re.Match object; span=(0, 7), match='стартап'>
# <re.Match object; span=(0, 7), match='стартап'>
# <re.Match object; span=(19, 26), match='стартап'>
# <re.Match object; span=(36, 43), match='стартап'>
# <re.Match object; span=(8, 15), match='стартап'>
# <re.Match object; span=(12, 19), match='стартап'>
# <re.Match object; span=(17, 24), match='стартап'>
# <re.Match object; span=(0, 7), match='стартап'>
# <re.Match object; span=(0, 7), match='стартап'>
# <re.Match object; span=(58, 65), match='стартап'>
# <re.Match object; span=(23, 30), match='стартап'>
# <re.Match object; span=(25, 32), match='стартап'>
# <re.Match object; span=(0, 7), match='стартап'>
# <re.Match object; span=(11, 18), match='стартап'>
# <re.Match object; span=(21, 28), match='стартап'>
# <re.Match object; span=(72, 79), match='стартап'>
# <re.Match object; span=(5, 12), match='стартап'>
# <re.Match object; span=(39, 46), match='стартап'>
# <re.Match object; span=(21, 28), match='стартап'>
# <re.Match object; span=(17, 24), match='стартап'>
# <re.Match object; span=(32, 39), match='стартап'>
# <re.Match object; span=(0, 7), match='стартап'>
# <re.Match object; span=(54, 61), match='стартап'>
# <re.Match object; span=(49, 56), match='стартап'>
# <re.Match object; span=(0, 7), match='стартап'>
# <re.Match object; span=(0, 7), match='стартап'>
# <re.Match object; span=(0, 7), match='стартап'>
# <re.Match object; span=(96, 103), match='стартап'>
# <re.Match object; span=(68, 75), match='стартап'>
# <re.Match object; span=(42, 49), match='стартап'>
# <re.Match object; span=(36, 43), match='стартап'>
# <re.Match object; span=(35, 42), match='стартап'>
# <re.Match object; span=(10, 17), match='стартап'>
# <re.Match object; span=(0, 7), match='стартап'>
# <re.Match object; span=(47, 54), match='стартап'>
# <re.Match object; span=(95, 102), match='стартап'>
# <re.Match object; span=(29, 36), match='стартап'>
# <re.Match object; span=(67, 74), match='стартап'>
# <re.Match object; span=(0, 7), match='стартап'>
# <re.Match object; span=(0, 7), match='стартап'>
# <re.Match object; span=(78, 85), match='стартап'>
# <re.Match object; span=(0, 7), match='стартап'>
# <re.Match object; span=(38, 45), match='стартап'>
# <re.Match object; span=(0, 7), match='стартап'>
# <re.Match object; span=(0, 7), match='стартап'>
# <re.Match object; span=(11, 18), match='стартап'>
# <re.Match object; span=(35, 42), match='стартап'>
# <re.Match object; span=(0, 7), match='стартап'>
# <re.Match object; span=(46, 53), match='стартап'>
# <re.Match object; span=(0, 7), match='стартап'>
# <re.Match object; span=(57, 64), match='стартап'>
# <re.Match object; span=(39, 46), match='стартап'>
# <re.Match object; span=(0, 7), match='стартап'>
# <re.Match object; span=(29, 36), match='стартап'>
# <re.Match object; span=(0, 7), match='стартап'>
# <re.Match object; span=(13, 20), match='стартап'>
# <re.Match object; span=(49, 56), match='стартап'>
# <re.Match object; span=(0, 7), match='стартап'>
# <re.Match object; span=(13, 20), match='стартап'>
# <re.Match object; span=(28, 35), match='стартап'>
# <re.Match object; span=(0, 7), match='стартап'>
# <re.Match object; span=(53, 60), match='стартап'>
# <re.Match object; span=(0, 7), match='стартап'>
# <re.Match object; span=(0, 7), match='стартап'>
# <re.Match object; span=(0, 7), match='стартап'>
# <re.Match object; span=(0, 7), match='стартап'>
# <re.Match object; span=(0, 7), match='стартап'>
# <re.Match object; span=(38, 45), match='стартап'>
# <re.Match object; span=(17, 24), match='стартап'>
# <re.Match object; span=(0, 7), match='стартап'>
# <re.Match object; span=(91, 98), match='стартап'>
# <re.Match object; span=(16, 23), match='стартап'>
# <re.Match object; span=(7, 14), match='стартап'>
# <re.Match object; span=(0, 7), match='стартап'>
# <re.Match object; span=(0, 7), match='стартап'>
# <re.Match object; span=(50, 57), match='стартап'>
# <re.Match object; span=(41, 48), match='стартап'>
# <re.Match object; span=(0, 7), match='стартап'>
# <re.Match object; span=(0, 7), match='стартап'>
# <re.Match object; span=(29, 36), match='стартап'>
# <re.Match object; span=(0, 7), match='стартап'>
# <re.Match object; span=(80, 87), match='стартап'>
# <re.Match object; span=(27, 34), match='стартап'>
# <re.Match object; span=(31, 38), match='стартап'>
# <re.Match object; span=(4, 11), match='стартап'>
# <re.Match object; span=(147, 154), match='стартап'>
# <re.Match object; span=(47, 54), match='стартап'>
# <re.Match object; span=(98, 105), match='стартап'>
# <re.Match object; span=(18, 25), match='стартап'>
# <re.Match object; span=(20, 27), match='стартап'>
# <re.Match object; span=(10, 17), match='стартап'>
# <re.Match object; span=(116, 123), match='стартап'>
# <re.Match object; span=(67, 74), match='стартап'>
# <re.Match object; span=(35, 42), match='стартап'>
# <re.Match object; span=(75, 82), match='стартап'>
# <re.Match object; span=(11, 18), match='стартап'>
# <re.Match object; span=(55, 62), match='стартап'>
# <re.Match object; span=(4, 11), match='стартап'>
# <re.Match object; span=(24, 31), match='стартап'>
# <re.Match object; span=(0, 7), match='стартап'>
# <re.Match object; span=(84, 91), match='стартап'>
# <re.Match object; span=(135, 142), match='стартап'>
# <re.Match object; span=(93, 100), match='стартап'>
# <re.Match object; span=(25, 32), match='стартап'>
# <re.Match object; span=(93, 100), match='стартап'>
# <re.Match object; span=(54, 61), match='стартап'>
# <re.Match object; span=(28, 35), match='стартап'>
# <re.Match object; span=(0, 7), match='стартап'>
# <re.Match object; span=(0, 7), match='стартап'>
# <re.Match object; span=(21, 28), match='стартап'>
# <re.Match object; span=(20, 27), match='стартап'>
# <re.Match object; span=(19, 26), match='стартап'>
# <re.Match object; span=(9, 16), match='стартап'>
# <re.Match object; span=(13, 20), match='стартап'>
# <re.Match object; span=(0, 7), match='стартап'>
# <re.Match object; span=(0, 7), match='стартап'>
# <re.Match object; span=(90, 97), match='стартап'>
# <re.Match object; span=(24, 31), match='стартап'>
# <re.Match object; span=(35, 42), match='стартап'>
# <re.Match object; span=(0, 7), match='стартап'>
# <re.Match object; span=(0, 7), match='стартап'>
# <re.Match object; span=(27, 34), match='стартап'>
# <re.Match object; span=(0, 7), match='стартап'>
# <re.Match object; span=(62, 69), match='стартап'>
# <re.Match object; span=(11, 18), match='стартап'>
# <re.Match object; span=(0, 7), match='стартап'>
# <re.Match object; span=(16, 23), match='стартап'>
# <re.Match object; span=(13, 20), match='стартап'>
# <re.Match object; span=(10, 17), match='стартап'>
# <re.Match object; span=(35, 42), match='стартап'>
# <re.Match object; span=(58, 65), match='стартап'>
# <re.Match object; span=(0, 7), match='стартап'>
# <re.Match object; span=(47, 54), match='стартап'>
# <re.Match object; span=(0, 7), match='стартап'>
# <re.Match object; span=(76, 83), match='стартап'>
# <re.Match object; span=(20, 27), match='стартап'>
# <re.Match object; span=(20, 27), match='стартап'>
# <re.Match object; span=(0, 7), match='стартап'>
# <re.Match object; span=(13, 20), match='стартап'>
# <re.Match object; span=(0, 7), match='стартап'>
# <re.Match object; span=(0, 7), match='стартап'>
# <re.Match object; span=(17, 24), match='стартап'>
# <re.Match object; span=(25, 32), match='стартап'>
# <re.Match object; span=(21, 28), match='стартап'>
# <re.Match object; span=(17, 24), match='стартап'>
# <re.Match object; span=(32, 39), match='стартап'>
# <re.Match object; span=(9, 16), match='стартап'>
# <re.Match object; span=(72, 79), match='стартап'>
# <re.Match object; span=(32, 39), match='стартап'>
# <re.Match object; span=(11, 18), match='стартап'>
# <re.Match object; span=(11, 18), match='стартап'>
# <re.Match object; span=(13, 20), match='стартап'>
# <re.Match object; span=(9, 16), match='стартап'>
# <re.Match object; span=(0, 7), match='стартап'>
# <re.Match object; span=(0, 7), match='стартап'>
# <re.Match object; span=(0, 7), match='стартап'>
# <re.Match object; span=(24, 31), match='стартап'>
# <re.Match object; span=(0, 7), match='стартап'>
# <re.Match object; span=(29, 36), match='стартап'>
# <re.Match object; span=(52, 59), match='стартап'>
# <re.Match object; span=(21, 28), match='стартап'>
# <re.Match object; span=(17, 24), match='стартап'>
# <re.Match object; span=(24, 31), match='стартап'>
# <re.Match object; span=(0, 7), match='стартап'>
# <re.Match object; span=(12, 19), match='стартап'>
# <re.Match object; span=(8, 15), match='стартап'>
# <re.Match object; span=(0, 7), match='стартап'>
# <re.Match object; span=(67, 74), match='стартап'>
# <re.Match object; span=(97, 104), match='стартап'>
# <re.Match object; span=(22, 29), match='стартап'>
# <re.Match object; span=(44, 51), match='стартап'>
# <re.Match object; span=(4, 11), match='стартап'>
# <re.Match object; span=(0, 7), match='стартап'>
# <re.Match object; span=(0, 7), match='стартап'>
# <re.Match object; span=(0, 7), match='стартап'>
# <re.Match object; span=(28, 35), match='стартап'>
# <re.Match object; span=(24, 31), match='стартап'>
# <re.Match object; span=(19, 26), match='стартап'>
# <re.Match object; span=(0, 7), match='стартап'>
# <re.Match object; span=(46, 53), match='стартап'>
# <re.Match object; span=(0, 7), match='стартап'>
# <re.Match object; span=(20, 27), match='стартап'>
# <re.Match object; span=(71, 78), match='стартап'>
# <re.Match object; span=(0, 7), match='стартап'>
# <re.Match object; span=(35, 42), match='стартап'>
# <re.Match object; span=(0, 7), match='стартап'>
# <re.Match object; span=(0, 7), match='стартап'>
# <re.Match object; span=(27, 34), match='стартап'>
# <re.Match object; span=(4, 11), match='стартап'>
# <re.Match object; span=(0, 7), match='стартап'>
# <re.Match object; span=(13, 20), match='стартап'>
# <re.Match object; span=(0, 7), match='стартап'>
# <re.Match object; span=(113, 120), match='стартап'>
# <re.Match object; span=(0, 7), match='стартап'>
# <re.Match object; span=(79, 86), match='стартап'>
# <re.Match object; span=(48, 55), match='стартап'>
# <re.Match object; span=(45, 52), match='стартап'>
# <re.Match object; span=(30, 37), match='стартап'>
# <re.Match object; span=(79, 86), match='стартап'>
# <re.Match object; span=(0, 7), match='стартап'>
# <re.Match object; span=(8, 15), match='стартап'>
# <re.Match object; span=(21, 28), match='стартап'>
# <re.Match object; span=(0, 7), match='стартап'>
# <re.Match object; span=(29, 36), match='стартап'>
# <re.Match object; span=(79, 86), match='стартап'>
# <re.Match object; span=(0, 7), match='стартап'>
# <re.Match object; span=(17, 24), match='стартап'>
# <re.Match object; span=(0, 7), match='стартап'>
# <re.Match object; span=(67, 74), match='стартап'>
# <re.Match object; span=(34, 41), match='стартап'>
# <re.Match object; span=(100, 107), match='стартап'>
# <re.Match object; span=(13, 20), match='стартап'>
# <re.Match object; span=(34, 41), match='стартап'>
# <re.Match object; span=(0, 7), match='стартап'>
# <re.Match object; span=(66, 73), match='стартап'>
# <re.Match object; span=(0, 7), match='стартап'>
# <re.Match object; span=(0, 7), match='стартап'>
# <re.Match object; span=(91, 98), match='стартап'>
# <re.Match object; span=(10, 17), match='стартап'>
# <re.Match object; span=(43, 50), match='стартап'>
# <re.Match object; span=(10, 17), match='стартап'>
# <re.Match object; span=(40, 47), match='стартап'>
# <re.Match object; span=(60, 67), match='стартап'>
# <re.Match object; span=(5, 12), match='стартап'>
# <re.Match object; span=(87, 94), match='стартап'>
# <re.Match object; span=(29, 36), match='стартап'>
# <re.Match object; span=(8, 15), match='стартап'>
# <re.Match object; span=(21, 28), match='стартап'>
# <re.Match object; span=(28, 35), match='стартап'>
# <re.Match object; span=(13, 20), match='стартап'>
# <re.Match object; span=(49, 56), match='стартап'>
# <re.Match object; span=(0, 7), match='стартап'>
# <re.Match object; span=(81, 88), match='стартап'>
# <re.Match object; span=(106, 113), match='стартап'>
# <re.Match object; span=(79, 86), match='стартап'>
# <re.Match object; span=(0, 7), match='стартап'>
# <re.Match object; span=(9, 16), match='стартап'>
# <re.Match object; span=(7, 14), match='стартап'>
# <re.Match object; span=(108, 115), match='стартап'>
# <re.Match object; span=(10, 17), match='стартап'>
# <re.Match object; span=(30, 37), match='стартап'>
# <re.Match object; span=(0, 7), match='стартап'>
# <re.Match object; span=(37, 44), match='стартап'>
# <re.Match object; span=(0, 7), match='стартап'>
# <re.Match object; span=(36, 43), match='стартап'>
# <re.Match object; span=(37, 44), match='стартап'>
# <re.Match object; span=(37, 44), match='стартап'>
# <re.Match object; span=(0, 7), match='стартап'>
# <re.Match object; span=(49, 56), match='стартап'>
# <re.Match object; span=(27, 34), match='стартап'>
# <re.Match object; span=(37, 44), match='стартап'>
# <re.Match object; span=(0, 7), match='стартап'>
# <re.Match object; span=(37, 44), match='стартап'>
# <re.Match object; span=(9, 16), match='стартап'>
# <re.Match object; span=(37, 44), match='стартап'>
# <re.Match object; span=(9, 16), match='стартап'>
# <re.Match object; span=(40, 47), match='стартап'>
# <re.Match object; span=(13, 20), match='стартап'>
# <re.Match object; span=(92, 99), match='стартап'>
# <re.Match object; span=(11, 18), match='стартап'>
# <re.Match object; span=(21, 28), match='стартап'>
# <re.Match object; span=(7, 14), match='стартап'>
# <re.Match object; span=(9, 16), match='стартап'>
# <re.Match object; span=(27, 34), match='стартап'>
# <re.Match object; span=(27, 34), match='стартап'>
# <re.Match object; span=(0, 7), match='стартап'>
# <re.Match object; span=(0, 7), match='стартап'>
# <re.Match object; span=(46, 53), match='стартап'>
# <re.Match object; span=(9, 16), match='стартап'>
# <re.Match object; span=(6, 13), match='стартап'>
# <re.Match object; span=(67, 74), match='стартап'>
# <re.Match object; span=(66, 73), match='стартап'>
# <re.Match object; span=(20, 27), match='стартап'>
# <re.Match object; span=(18, 25), match='стартап'>
# <re.Match object; span=(24, 31), match='стартап'>
# <re.Match object; span=(72, 79), match='стартап'>
# <re.Match object; span=(26, 33), match='стартап'>
# <re.Match object; span=(9, 16), match='стартап'>
# <re.Match object; span=(32, 39), match='стартап'>
# <re.Match object; span=(0, 7), match='стартап'>
# <re.Match object; span=(55, 62), match='стартап'>
# <re.Match object; span=(0, 7), match='стартап'>
# <re.Match object; span=(29, 36), match='стартап'>
# <re.Match object; span=(18, 25), match='стартап'>
# <re.Match object; span=(12, 19), match='стартап'>
# <re.Match object; span=(69, 76), match='стартап'>
# <re.Match object; span=(17, 24), match='стартап'>
# <re.Match object; span=(28, 35), match='стартап'>
# <re.Match object; span=(0, 7), match='стартап'>
# <re.Match object; span=(17, 24), match='стартап'>
# <re.Match object; span=(25, 32), match='стартап'>
# <re.Match object; span=(26, 33), match='стартап'>
# <re.Match object; span=(10, 17), match='стартап'>
# <re.Match object; span=(41, 48), match='стартап'>
# <re.Match object; span=(26, 33), match='стартап'>
# <re.Match object; span=(13, 20), match='стартап'>
# <re.Match object; span=(0, 7), match='стартап'>
# <re.Match object; span=(0, 7), match='стартап'>
# <re.Match object; span=(70, 77), match='стартап'>
# <re.Match object; span=(62, 69), match='стартап'>
# <re.Match object; span=(9, 16), match='стартап'>
# <re.Match object; span=(0, 7), match='стартап'>
# <re.Match object; span=(30, 37), match='стартап'>
# <re.Match object; span=(29, 36), match='стартап'>
# <re.Match object; span=(43, 50), match='стартап'>
# <re.Match object; span=(71, 78), match='стартап'>
# <re.Match object; span=(27, 34), match='стартап'>
# <re.Match object; span=(73, 80), match='стартап'>
# <re.Match object; span=(36, 43), match='стартап'>
# <re.Match object; span=(102, 109), match='стартап'>
# <re.Match object; span=(67, 74), match='стартап'>
# <re.Match object; span=(90, 97), match='стартап'>
# <re.Match object; span=(42, 49), match='стартап'>
# <re.Match object; span=(16, 23), match='стартап'>
# <re.Match object; span=(0, 7), match='стартап'>
# <re.Match object; span=(23, 30), match='стартап'>
# <re.Match object; span=(47, 54), match='стартап'>
# <re.Match object; span=(17, 24), match='стартап'>
# <re.Match object; span=(72, 79), match='стартап'>
# <re.Match object; span=(117, 124), match='стартап'>
# <re.Match object; span=(17, 24), match='стартап'>
# <re.Match object; span=(16, 23), match='стартап'>
# <re.Match object; span=(117, 124), match='стартап'>
# <re.Match object; span=(0, 7), match='стартап'>
# <re.Match object; span=(0, 7), match='стартап'>
# <re.Match object; span=(19, 26), match='стартап'>
# <re.Match object; span=(72, 79), match='стартап'>
# <re.Match object; span=(33, 40), match='стартап'>
# <re.Match object; span=(117, 124), match='стартап'>
# <re.Match object; span=(40, 47), match='стартап'>
# <re.Match object; span=(42, 49), match='стартап'>
# <re.Match object; span=(26, 33), match='стартап'>
# <re.Match object; span=(0, 7), match='стартап'>
# <re.Match object; span=(79, 86), match='стартап'>
# <re.Match object; span=(72, 79), match='стартап'>
# <re.Match object; span=(15, 22), match='стартап'>
# <re.Match object; span=(72, 79), match='стартап'>
# <re.Match object; span=(8, 15), match='стартап'>
# <re.Match object; span=(0, 7), match='стартап'>
# <re.Match object; span=(77, 84), match='стартап'>
# <re.Match object; span=(117, 124), match='стартап'>
# <re.Match object; span=(127, 134), match='стартап'>
# <re.Match object; span=(7, 14), match='стартап'>
# <re.Match object; span=(46, 53), match='стартап'>
# <re.Match object; span=(13, 20), match='стартап'>
# <re.Match object; span=(19, 26), match='стартап'>
# <re.Match object; span=(25, 32), match='стартап'>
# <re.Match object; span=(23, 30), match='стартап'>
# <re.Match object; span=(0, 7), match='стартап'>
# <re.Match object; span=(51, 58), match='стартап'>
# <re.Match object; span=(53, 60), match='стартап'>
# <re.Match object; span=(104, 111), match='стартап'>
# <re.Match object; span=(0, 7), match='стартап'>
# <re.Match object; span=(4, 11), match='стартап'>
# <re.Match object; span=(9, 16), match='стартап'>
# <re.Match object; span=(38, 45), match='стартап'>
# <re.Match object; span=(15, 22), match='стартап'>
# <re.Match object; span=(9, 16), match='стартап'>
# <re.Match object; span=(0, 7), match='стартап'>
# <re.Match object; span=(0, 7), match='стартап'>
# <re.Match object; span=(72, 79), match='стартап'>
# <re.Match object; span=(30, 37), match='стартап'>
# <re.Match object; span=(94, 101), match='стартап'>
# <re.Match object; span=(24, 31), match='стартап'>
# <re.Match object; span=(0, 7), match='стартап'>
# <re.Match object; span=(99, 106), match='стартап'>
# <re.Match object; span=(56, 63), match='стартап'>
# <re.Match object; span=(32, 39), match='стартап'>
# <re.Match object; span=(94, 101), match='стартап'>
# <re.Match object; span=(15, 22), match='стартап'>
# <re.Match object; span=(40, 47), match='стартап'>
# <re.Match object; span=(45, 52), match='стартап'>
# <re.Match object; span=(9, 16), match='стартап'>
# <re.Match object; span=(32, 39), match='стартап'>
# <re.Match object; span=(22, 29), match='стартап'>
# <re.Match object; span=(101, 108), match='стартап'>
# <re.Match object; span=(78, 85), match='стартап'>
# <re.Match object; span=(53, 60), match='стартап'>
# <re.Match object; span=(0, 7), match='стартап'>
# <re.Match object; span=(0, 7), match='стартап'>
# <re.Match object; span=(52, 59), match='стартап'>
# <re.Match object; span=(12, 19), match='стартап'>
# <re.Match object; span=(31, 38), match='стартап'>
# <re.Match object; span=(64, 71), match='стартап'>
# <re.Match object; span=(53, 60), match='стартап'>
# <re.Match object; span=(12, 19), match='стартап'>
# <re.Match object; span=(94, 101), match='стартап'>
# <re.Match object; span=(32, 39), match='стартап'>
# <re.Match object; span=(66, 73), match='стартап'>
# <re.Match object; span=(88, 95), match='стартап'>
# <re.Match object; span=(55, 62), match='стартап'>
# <re.Match object; span=(66, 73), match='стартап'>
# <re.Match object; span=(13, 20), match='стартап'>
# <re.Match object; span=(11, 18), match='стартап'>
# <re.Match object; span=(96, 103), match='стартап'>
# <re.Match object; span=(0, 7), match='стартап'>
# <re.Match object; span=(29, 36), match='стартап'>
# <re.Match object; span=(84, 91), match='стартап'>
# <re.Match object; span=(9, 16), match='стартап'>
# <re.Match object; span=(34, 41), match='стартап'>
# <re.Match object; span=(54, 61), match='стартап'>
# <re.Match object; span=(0, 7), match='стартап'>
# <re.Match object; span=(53, 60), match='стартап'>
# <re.Match object; span=(94, 101), match='стартап'>
# <re.Match object; span=(11, 18), match='стартап'>
# <re.Match object; span=(45, 52), match='стартап'>
# <re.Match object; span=(0, 7), match='стартап'>
# <re.Match object; span=(0, 7), match='стартап'>
# <re.Match object; span=(11, 18), match='стартап'>
# <re.Match object; span=(59, 66), match='стартап'>
# <re.Match object; span=(13, 20), match='стартап'>
# <re.Match object; span=(0, 7), match='стартап'>
# <re.Match object; span=(11, 18), match='стартап'>
# <re.Match object; span=(8, 15), match='стартап'>
# <re.Match object; span=(11, 18), match='стартап'>
# <re.Match object; span=(53, 60), match='стартап'>
# <re.Match object; span=(6, 13), match='стартап'>
# <re.Match object; span=(9, 16), match='стартап'>
# <re.Match object; span=(34, 41), match='стартап'>
# <re.Match object; span=(37, 44), match='стартап'>
# <re.Match object; span=(25, 32), match='стартап'>
# <re.Match object; span=(0, 7), match='стартап'>
# <re.Match object; span=(0, 7), match='стартап'>
# <re.Match object; span=(39, 46), match='стартап'>
# <re.Match object; span=(9, 16), match='стартап'>
# <re.Match object; span=(0, 7), match='стартап'>
# <re.Match object; span=(96, 103), match='стартап'>
# <re.Match object; span=(37, 44), match='стартап'>
# <re.Match object; span=(18, 25), match='стартап'>
# <re.Match object; span=(9, 16), match='стартап'>
# <re.Match object; span=(9, 16), match='стартап'>
# <re.Match object; span=(9, 16), match='стартап'>
# <re.Match object; span=(63, 70), match='стартап'>
# <re.Match object; span=(17, 24), match='стартап'>
# <re.Match object; span=(20, 27), match='стартап'>
# <re.Match object; span=(17, 24), match='стартап'>
# <re.Match object; span=(83, 90), match='стартап'>
# <re.Match object; span=(0, 7), match='стартап'>
# <re.Match object; span=(41, 48), match='стартап'>
# <re.Match object; span=(30, 37), match='стартап'>
# <re.Match object; span=(5, 12), match='стартап'>
# <re.Match object; span=(9, 16), match='стартап'>
# <re.Match object; span=(69, 76), match='стартап'>
# <re.Match object; span=(14, 21), match='стартап'>
# <re.Match object; span=(11, 18), match='стартап'>
# <re.Match object; span=(43, 50), match='стартап'>
# <re.Match object; span=(28, 35), match='стартап'>
# <re.Match object; span=(0, 7), match='стартап'>
# <re.Match object; span=(0, 7), match='стартап'>
# <re.Match object; span=(12, 19), match='стартап'>
# <re.Match object; span=(0, 7), match='стартап'>
# <re.Match object; span=(90, 97), match='стартап'>
# <re.Match object; span=(12, 19), match='стартап'>
# <re.Match object; span=(36, 43), match='стартап'>
# <re.Match object; span=(28, 35), match='стартап'>
# <re.Match object; span=(61, 68), match='стартап'>
# <re.Match object; span=(85, 92), match='стартап'>
# <re.Match object; span=(9, 16), match='стартап'>
# <re.Match object; span=(22, 29), match='стартап'>
# <re.Match object; span=(0, 7), match='стартап'>
# <re.Match object; span=(34, 41), match='стартап'>
# <re.Match object; span=(0, 7), match='стартап'>
# <re.Match object; span=(72, 79), match='стартап'>
# <re.Match object; span=(21, 28), match='стартап'>
# <re.Match object; span=(40, 47), match='стартап'>
# <re.Match object; span=(15, 22), match='стартап'>
# <re.Match object; span=(51, 58), match='стартап'>
# <re.Match object; span=(56, 63), match='стартап'>
# <re.Match object; span=(38, 45), match='стартап'>
# <re.Match object; span=(0, 7), match='стартап'>
# <re.Match object; span=(0, 7), match='стартап'>
# <re.Match object; span=(18, 25), match='стартап'>
# <re.Match object; span=(37, 44), match='стартап'>
# <re.Match object; span=(4, 11), match='стартап'>
# <re.Match object; span=(13, 20), match='стартап'>
# <re.Match object; span=(35, 42), match='стартап'>
# <re.Match object; span=(19, 26), match='стартап'>
# <re.Match object; span=(37, 44), match='стартап'>
# <re.Match object; span=(37, 44), match='стартап'>
# <re.Match object; span=(81, 88), match='стартап'>
# <re.Match object; span=(0, 7), match='стартап'>
# <re.Match object; span=(42, 49), match='стартап'>
# <re.Match object; span=(25, 32), match='стартап'>
# <re.Match object; span=(86, 93), match='стартап'>
# <re.Match object; span=(0, 7), match='стартап'>
# <re.Match object; span=(91, 98), match='стартап'>
# <re.Match object; span=(0, 7), match='стартап'>
# <re.Match object; span=(11, 18), match='стартап'>
# <re.Match object; span=(96, 103), match='стартап'>
# <re.Match object; span=(42, 49), match='стартап'>
# <re.Match object; span=(0, 7), match='стартап'>
# <re.Match object; span=(60, 67), match='стартап'>
# <re.Match object; span=(0, 7), match='стартап'>
# <re.Match object; span=(7, 14), match='стартап'>
# <re.Match object; span=(7, 14), match='стартап'>
# <re.Match object; span=(61, 68), match='стартап'>
# <re.Match object; span=(20, 27), match='стартап'>
# <re.Match object; span=(25, 32), match='стартап'>
# <re.Match object; span=(19, 26), match='стартап'>
# <re.Match object; span=(28, 35), match='стартап'>
# <re.Match object; span=(28, 35), match='стартап'>
# <re.Match object; span=(58, 65), match='стартап'>
# <re.Match object; span=(5, 12), match='стартап'>
# <re.Match object; span=(41, 48), match='стартап'>
# <re.Match object; span=(0, 7), match='стартап'>
# <re.Match object; span=(96, 103), match='стартап'>
# <re.Match object; span=(51, 58), match='стартап'>
# <re.Match object; span=(8, 15), match='стартап'>
# <re.Match object; span=(75, 82), match='стартап'>
# <re.Match object; span=(7, 14), match='стартап'>
# <re.Match object; span=(42, 49), match='стартап'>
# <re.Match object; span=(24, 31), match='стартап'>
# <re.Match object; span=(92, 99), match='стартап'>
# <re.Match object; span=(43, 50), match='стартап'>
# <re.Match object; span=(18, 25), match='стартап'>
# <re.Match object; span=(40, 47), match='стартап'>
# <re.Match object; span=(67, 74), match='стартап'>
# <re.Match object; span=(37, 44), match='стартап'>
# <re.Match object; span=(0, 7), match='стартап'>
# <re.Match object; span=(0, 7), match='стартап'>
# <re.Match object; span=(14, 21), match='стартап'>
# <re.Match object; span=(54, 61), match='стартап'>
# <re.Match object; span=(24, 31), match='стартап'>
# <re.Match object; span=(77, 84), match='стартап'>
# <re.Match object; span=(0, 7), match='стартап'>
# <re.Match object; span=(35, 42), match='стартап'>
# <re.Match object; span=(9, 16), match='стартап'>
# <re.Match object; span=(7, 14), match='стартап'>
# <re.Match object; span=(55, 62), match='стартап'>
# <re.Match object; span=(38, 45), match='стартап'>
# <re.Match object; span=(7, 14), match='стартап'>
# <re.Match object; span=(10, 17), match='стартап'>
# <re.Match object; span=(22, 29), match='стартап'>
# <re.Match object; span=(0, 7), match='стартап'>
# <re.Match object; span=(120, 127), match='стартап'>
# <re.Match object; span=(0, 7), match='стартап'>
# <re.Match object; span=(36, 43), match='стартап'>
# <re.Match object; span=(12, 19), match='стартап'>
# <re.Match object; span=(21, 28), match='стартап'>
# <re.Match object; span=(44, 51), match='стартап'>
# <re.Match object; span=(36, 43), match='стартап'>
# <re.Match object; span=(25, 32), match='стартап'>
# <re.Match object; span=(28, 35), match='стартап'>
# <re.Match object; span=(48, 55), match='стартап'>
# <re.Match object; span=(25, 32), match='стартап'>
# <re.Match object; span=(19, 26), match='стартап'>
# <re.Match object; span=(77, 84), match='стартап'>
# <re.Match object; span=(50, 57), match='стартап'>
# <re.Match object; span=(40, 47), match='стартап'>
# <re.Match object; span=(71, 78), match='стартап'>
# <re.Match object; span=(0, 7), match='стартап'>
# <re.Match object; span=(0, 7), match='стартап'>
# <re.Match object; span=(0, 7), match='стартап'>
# <re.Match object; span=(25, 32), match='стартап'>
# <re.Match object; span=(41, 48), match='стартап'>
# <re.Match object; span=(16, 23), match='стартап'>
# <re.Match object; span=(53, 60), match='стартап'>
# <re.Match object; span=(36, 43), match='стартап'>
# <re.Match object; span=(9, 16), match='стартап'>
# <re.Match object; span=(47, 54), match='стартап'>
# <re.Match object; span=(100, 107), match='стартап'>
# <re.Match object; span=(31, 38), match='стартап'>
# <re.Match object; span=(29, 36), match='стартап'>
# <re.Match object; span=(43, 50), match='стартап'>
# <re.Match object; span=(17, 24), match='стартап'>
# <re.Match object; span=(0, 7), match='стартап'>
# <re.Match object; span=(34, 41), match='стартап'>
# <re.Match object; span=(0, 7), match='стартап'>
# <re.Match object; span=(53, 60), match='стартап'>
# <re.Match object; span=(49, 56), match='стартап'>
# <re.Match object; span=(118, 125), match='стартап'>
# <re.Match object; span=(106, 113), match='стартап'>
# <re.Match object; span=(0, 7), match='стартап'>
# <re.Match object; span=(57, 64), match='стартап'>
# <re.Match object; span=(82, 89), match='стартап'>
# <re.Match object; span=(35, 42), match='стартап'>
# <re.Match object; span=(83, 90), match='стартап'>
# <re.Match object; span=(0, 7), match='стартап'>
# <re.Match object; span=(0, 7), match='стартап'>
# <re.Match object; span=(18, 25), match='стартап'>
# <re.Match object; span=(0, 7), match='стартап'>
# <re.Match object; span=(0, 7), match='стартап'>
# <re.Match object; span=(28, 35), match='стартап'>
# <re.Match object; span=(17, 24), match='стартап'>
# <re.Match object; span=(57, 64), match='стартап'>
# <re.Match object; span=(31, 38), match='стартап'>
# <re.Match object; span=(19, 26), match='стартап'>
# <re.Match object; span=(68, 75), match='стартап'>
# <re.Match object; span=(37, 44), match='стартап'>
# <re.Match object; span=(0, 7), match='стартап'>
# <re.Match object; span=(21, 28), match='стартап'>
# <re.Match object; span=(13, 20), match='стартап'>
# <re.Match object; span=(0, 7), match='стартап'>
# <re.Match object; span=(0, 7), match='стартап'>
# <re.Match object; span=(145, 152), match='стартап'>
# <re.Match object; span=(120, 127), match='стартап'>
# <re.Match object; span=(71, 78), match='стартап'>
# <re.Match object; span=(31, 38), match='стартап'>
# <re.Match object; span=(0, 7), match='стартап'>
# <re.Match object; span=(23, 30), match='стартап'>
# <re.Match object; span=(0, 7), match='стартап'>
# <re.Match object; span=(20, 27), match='стартап'>
# <re.Match object; span=(67, 74), match='стартап'>
# <re.Match object; span=(0, 7), match='стартап'>
# <re.Match object; span=(0, 7), match='стартап'>
# <re.Match object; span=(65, 72), match='стартап'>
# <re.Match object; span=(51, 58), match='стартап'>
# <re.Match object; span=(7, 14), match='стартап'>
# <re.Match object; span=(6, 13), match='стартап'>
# <re.Match object; span=(0, 7), match='стартап'>
# <re.Match object; span=(30, 37), match='стартап'>
# <re.Match object; span=(65, 72), match='стартап'>
# <re.Match object; span=(9, 16), match='стартап'>
# <re.Match object; span=(28, 35), match='стартап'>
# <re.Match object; span=(72, 79), match='стартап'>
# <re.Match object; span=(17, 24), match='стартап'>
# <re.Match object; span=(21, 28), match='стартап'>
# <re.Match object; span=(0, 7), match='стартап'>
# <re.Match object; span=(0, 7), match='стартап'>
# <re.Match object; span=(67, 74), match='стартап'>
# <re.Match object; span=(4, 11), match='стартап'>
# <re.Match object; span=(5, 12), match='стартап'>
# <re.Match object; span=(44, 51), match='стартап'>
# <re.Match object; span=(0, 7), match='стартап'>
# <re.Match object; span=(14, 21), match='стартап'>
# <re.Match object; span=(0, 7), match='стартап'>
# <re.Match object; span=(0, 7), match='стартап'>
# <re.Match object; span=(44, 51), match='стартап'>
# <re.Match object; span=(13, 20), match='стартап'>
# <re.Match object; span=(12, 19), match='стартап'>
# <re.Match object; span=(0, 7), match='стартап'>
# <re.Match object; span=(0, 7), match='стартап'>
# <re.Match object; span=(0, 7), match='стартап'>
# <re.Match object; span=(6, 13), match='стартап'>
# <re.Match object; span=(5, 12), match='стартап'>
# <re.Match object; span=(0, 7), match='стартап'>
# <re.Match object; span=(26, 33), match='стартап'>
# <re.Match object; span=(0, 7), match='стартап'>
# <re.Match object; span=(164, 171), match='стартап'>
# <re.Match object; span=(77, 84), match='стартап'>
# <re.Match object; span=(30, 37), match='стартап'>
# <re.Match object; span=(36, 43), match='стартап'>
# <re.Match object; span=(97, 104), match='стартап'>
# <re.Match object; span=(0, 7), match='стартап'>
# <re.Match object; span=(18, 25), match='стартап'>
# <re.Match object; span=(7, 14), match='стартап'>
# <re.Match object; span=(0, 7), match='стартап'>
# <re.Match object; span=(11, 18), match='стартап'>
# <re.Match object; span=(0, 7), match='стартап'>
# <re.Match object; span=(36, 43), match='стартап'>
# <re.Match object; span=(61, 68), match='стартап'>
# <re.Match object; span=(0, 7), match='стартап'>
# <re.Match object; span=(22, 29), match='стартап'>
# <re.Match object; span=(41, 48), match='стартап'>
# <re.Match object; span=(0, 7), match='стартап'>
# <re.Match object; span=(45, 52), match='стартап'>
# <re.Match object; span=(39, 46), match='стартап'>
# <re.Match object; span=(9, 16), match='стартап'>
# <re.Match object; span=(16, 23), match='стартап'>
# <re.Match object; span=(65, 72), match='стартап'>
# <re.Match object; span=(14, 21), match='стартап'>
# <re.Match object; span=(21, 28), match='стартап'>
# <re.Match object; span=(225, 232), match='стартап'>
# <re.Match object; span=(67, 74), match='стартап'>
# <re.Match object; span=(37, 44), match='стартап'>
# <re.Match object; span=(17, 24), match='стартап'>
# <re.Match object; span=(50, 57), match='стартап'>
# <re.Match object; span=(25, 32), match='стартап'>
# <re.Match object; span=(0, 7), match='стартап'>
# <re.Match object; span=(25, 32), match='стартап'>
# <re.Match object; span=(0, 7), match='стартап'>
# <re.Match object; span=(9, 16), match='стартап'>
# <re.Match object; span=(68, 75), match='стартап'>
# <re.Match object; span=(0, 7), match='стартап'>
# <re.Match object; span=(38, 45), match='стартап'>
# <re.Match object; span=(9, 16), match='стартап'>
# <re.Match object; span=(11, 18), match='стартап'>
# <re.Match object; span=(7, 14), match='стартап'>
# <re.Match object; span=(0, 7), match='стартап'>
# <re.Match object; span=(33, 40), match='стартап'>
# <re.Match object; span=(9, 16), match='стартап'>
# <re.Match object; span=(43, 50), match='стартап'>
# <re.Match object; span=(62, 69), match='стартап'>
# <re.Match object; span=(10, 17), match='стартап'>
# <re.Match object; span=(33, 40), match='стартап'>
# <re.Match object; span=(22, 29), match='стартап'>
# <re.Match object; span=(8, 15), match='стартап'>
# <re.Match object; span=(29, 36), match='стартап'>
# <re.Match object; span=(23, 30), match='стартап'>
# <re.Match object; span=(86, 93), match='стартап'>
# <re.Match object; span=(51, 58), match='стартап'>
# <re.Match object; span=(71, 78), match='стартап'>
# <re.Match object; span=(30, 37), match='стартап'>
# <re.Match object; span=(0, 7), match='стартап'>
# <re.Match object; span=(24, 31), match='стартап'>
# <re.Match object; span=(13, 20), match='стартап'>
# <re.Match object; span=(34, 41), match='стартап'>
# <re.Match object; span=(9, 16), match='стартап'>
# <re.Match object; span=(17, 24), match='стартап'>
# <re.Match object; span=(157, 164), match='стартап'>
# <re.Match object; span=(15, 22), match='стартап'>
# <re.Match object; span=(6, 13), match='стартап'>
# <re.Match object; span=(68, 75), match='стартап'>
# <re.Match object; span=(4, 11), match='стартап'>
# <re.Match object; span=(51, 58), match='стартап'>
# <re.Match object; span=(29, 36), match='стартап'>
# <re.Match object; span=(36, 43), match='стартап'>
# <re.Match object; span=(41, 48), match='стартап'>
# <re.Match object; span=(13, 20), match='стартап'>
# <re.Match object; span=(12, 19), match='стартап'>
# <re.Match object; span=(0, 7), match='стартап'>
# <re.Match object; span=(71, 78), match='стартап'>
# <re.Match object; span=(110, 117), match='стартап'>
# <re.Match object; span=(30, 37), match='стартап'>
# <re.Match object; span=(29, 36), match='стартап'>
# <re.Match object; span=(13, 20), match='стартап'>
# <re.Match object; span=(16, 23), match='стартап'>
# <re.Match object; span=(9, 16), match='стартап'>
# <re.Match object; span=(26, 33), match='стартап'>
# <re.Match object; span=(72, 79), match='стартап'>
# <re.Match object; span=(19, 26), match='стартап'>
# <re.Match object; span=(0, 7), match='стартап'>
# <re.Match object; span=(30, 37), match='стартап'>
# <re.Match object; span=(19, 26), match='стартап'>
# <re.Match object; span=(4, 11), match='стартап'>
# <re.Match object; span=(8, 15), match='стартап'>
# <re.Match object; span=(29, 36), match='стартап'>
# <re.Match object; span=(0, 7), match='стартап'>
# <re.Match object; span=(84, 91), match='стартап'>
# <re.Match object; span=(34, 41), match='стартап'>
# <re.Match object; span=(15, 22), match='стартап'>
# <re.Match object; span=(41, 48), match='стартап'>
# <re.Match object; span=(81, 88), match='стартап'>
# <re.Match object; span=(10, 17), match='стартап'>
# <re.Match object; span=(21, 28), match='стартап'>
# <re.Match object; span=(12, 19), match='стартап'>
# <re.Match object; span=(32, 39), match='стартап'>
# <re.Match object; span=(36, 43), match='стартап'>
# <re.Match object; span=(15, 22), match='стартап'>
# <re.Match object; span=(17, 24), match='стартап'>
# <re.Match object; span=(57, 64), match='стартап'>
# <re.Match object; span=(7, 14), match='стартап'>
# <re.Match object; span=(70, 77), match='стартап'>
# <re.Match object; span=(40, 47), match='стартап'>
# <re.Match object; span=(69, 76), match='стартап'>
# <re.Match object; span=(21, 28), match='стартап'>
# <re.Match object; span=(30, 37), match='стартап'>
# <re.Match object; span=(16, 23), match='стартап'>
# <re.Match object; span=(30, 37), match='стартап'>
# <re.Match object; span=(16, 23), match='стартап'>
# <re.Match object; span=(89, 96), match='стартап'>
# <re.Match object; span=(33, 40), match='стартап'>
# <re.Match object; span=(75, 82), match='стартап'>
# <re.Match object; span=(37, 44), match='стартап'>
# <re.Match object; span=(47, 54), match='стартап'>
# <re.Match object; span=(54, 61), match='стартап'>
# <re.Match object; span=(40, 47), match='стартап'>
# <re.Match object; span=(45, 52), match='стартап'>
# <re.Match object; span=(93, 100), match='стартап'>
# <re.Match object; span=(12, 19), match='стартап'>
# <re.Match object; span=(22, 29), match='стартап'>
# <re.Match object; span=(12, 19), match='стартап'>
# <re.Match object; span=(0, 7), match='стартап'>
# <re.Match object; span=(65, 72), match='стартап'>
# <re.Match object; span=(0, 7), match='стартап'>
# <re.Match object; span=(24, 31), match='стартап'>
# <re.Match object; span=(0, 7), match='стартап'>
# <re.Match object; span=(22, 29), match='стартап'>
# <re.Match object; span=(16, 23), match='стартап'>
# <re.Match object; span=(0, 7), match='стартап'>
# <re.Match object; span=(31, 38), match='стартап'>
# <re.Match object; span=(21, 28), match='стартап'>
# <re.Match object; span=(0, 7), match='стартап'>
# <re.Match object; span=(0, 7), match='стартап'>
# <re.Match object; span=(68, 75), match='стартап'>
# <re.Match object; span=(18, 25), match='стартап'>
# <re.Match object; span=(0, 7), match='стартап'>
# <re.Match object; span=(35, 42), match='стартап'>
# <re.Match object; span=(9, 16), match='стартап'>
# <re.Match object; span=(15, 22), match='стартап'>
# <re.Match object; span=(44, 51), match='стартап'>
# <re.Match object; span=(26, 33), match='стартап'>
# <re.Match object; span=(16, 23), match='стартап'>
# <re.Match object; span=(76, 83), match='стартап'>
# <re.Match object; span=(27, 34), match='стартап'>
# <re.Match object; span=(95, 102), match='стартап'>
# <re.Match object; span=(69, 76), match='стартап'>
# <re.Match object; span=(64, 71), match='стартап'>
# <re.Match object; span=(0, 7), match='стартап'>
# <re.Match object; span=(49, 56), match='стартап'>
# <re.Match object; span=(7, 14), match='стартап'>
# <re.Match object; span=(40, 47), match='стартап'>
# <re.Match object; span=(31, 38), match='стартап'>
# <re.Match object; span=(16, 23), match='стартап'>
# <re.Match object; span=(0, 7), match='стартап'>
# <re.Match object; span=(19, 26), match='стартап'>
# <re.Match object; span=(112, 119), match='стартап'>
# <re.Match object; span=(0, 7), match='стартап'>
# <re.Match object; span=(108, 115), match='стартап'>
# <re.Match object; span=(27, 34), match='стартап'>
# <re.Match object; span=(35, 42), match='стартап'>
# <re.Match object; span=(23, 30), match='стартап'>
# <re.Match object; span=(31, 38), match='стартап'>
# <re.Match object; span=(13, 20), match='стартап'>
# <re.Match object; span=(22, 29), match='стартап'>
# <re.Match object; span=(17, 24), match='стартап'>
# <re.Match object; span=(0, 7), match='стартап'>
# <re.Match object; span=(0, 7), match='стартап'>
# <re.Match object; span=(233, 240), match='стартап'>
# <re.Match object; span=(0, 7), match='стартап'>
# <re.Match object; span=(13, 20), match='стартап'>
# <re.Match object; span=(0, 7), match='стартап'>
# <re.Match object; span=(17, 24), match='стартап'>
