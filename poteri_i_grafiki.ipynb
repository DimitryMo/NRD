# %%
import pandas as pd
import matplotlib.pyplot as plt
import pandas as pd
from tqdm import tqdm
import numpy as np

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
# %%time
df = pd.read_csv('/content/drive/My Drive/allhabr_weights.csv')
# Out:
# CPU times: user 37.9 s, sys: 6.14 s, total: 44.1 s
# Wall time: 1min 14s

# %%
df.rename(columns={'fintech_0.18000000000000005':'fintech_0.18',
                   'fintech_0.060000000000000005':'fintech_0.06',
                   'fintech_0.08000000000000002':'fintech_0.08',
                   'fintech_0.09000000000000001':'fintech_0.09',
                   'fintech_0.11000000000000001':'fintech_0.11',
                   'fintech_0.12000000000000001':'fintech_0.12',
                   'fintech_0.15000000000000002':'fintech_0.15',
                   'fintech_0.16000000000000003':'fintech_0.16',
                   'fintech_0.17000000000000004':'fintech_0.17',
                   'fintech_0.2':'fintech_0.20',
                   'fintech_0.1':'fintech_0.10'}, inplace=True)

# %%
fint = []
for i in tqdm(range(5,21)):
    a=[]
    if i <=9:
      for j in range(len(df['fintech_0.0{}'.format(i)])):
        if df['fintech_0.0{}'.format(i)][j]==1:
          a.append(j)
        else:
          j+=1
    else:
      for j in range(len(df['fintech_0.{}'.format(i)])):
        if df['fintech_0.{}'.format(i)][j]==1:
          a.append(j)
        else:
          j+=1
    fint.append(a)
len(fint)
# Out:
# 100%|██████████| 16/16 [00:26<00:00,  1.69s/it]
# 16

# %%
razn=list()
for i in range(len(fint)-1):
  a=[]
  a=list(set(fint[i])-set(fint[i+1]))
  razn.append(a)
len(razn)
# Out:
# 15

# %%
razn1 = df.iloc[razn[1]].reset_index()
razn2 = df.iloc[razn[2]].reset_index()
razn3 = df.iloc[razn[3]].reset_index()
razn4 = df.iloc[razn[4]].reset_index()
razn5 = df.iloc[razn[5]].reset_index()
razn6 = df.iloc[razn[6]].reset_index()
razn7 = df.iloc[razn[7]].reset_index()
razn8 = df.iloc[razn[8]].reset_index()
razn9 = df.iloc[razn[9]].reset_index()
razn10 = df.iloc[razn[10]].reset_index()
razn11 = df.iloc[razn[11]].reset_index()
razn12 = df.iloc[razn[12]].reset_index()
razn13 = df.iloc[razn[13]].reset_index()
razn14 = df.iloc[razn[14]].reset_index()

# %% [markdown]
# ###Ужасная херня для всех(пока 6 разностей)

# %%
b=[]
c=[]
for i in razn1['hubs']:
  b.append(i.split())
for j in b:
  for k in j:
    c.append(k)
f = dict()
for i in c:
  if i not in f:
    f['{}'.format(i)] = 1
  else:
    f['{}'.format(i)] += 1
forgraph=list(f.items())
forgraph.sort(key=lambda x:x[1], reverse=True)
for i in forgraph:
  if i[0]=='Блог' or i[0]=='компании' or i[0]=='в':
      forgraph.remove(i)
x1=[]
y1=[]
for i in forgraph:
  x1.append(i[0])
  y1.append(i[1])
#Для 2
b=[]
c=[]
for i in razn2['hubs']:
  b.append(i.split())
for j in b:
  for k in j:
    c.append(k)
f = dict()
for i in c:
  if i not in f:
    f['{}'.format(i)] = 1
  else:
    f['{}'.format(i)] += 1
forgraph=list(f.items())
forgraph.sort(key=lambda x:x[1], reverse=True)
for i in forgraph:
  if i[0]=='Блог' or i[0]=='компании' or i[0]=='в':
      forgraph.remove(i)
x2=[]
y2=[]
for i in forgraph:
  x2.append(i[0])
  y2.append(i[1])
#Для 3
b=[]
c=[]
for i in razn3['hubs']:
  b.append(i.split())
for j in b:
  for k in j:
    c.append(k)
f = dict()
for i in c:
  if i not in f:
    f['{}'.format(i)] = 1
  else:
    f['{}'.format(i)] += 1
forgraph=list(f.items())
forgraph.sort(key=lambda x:x[1], reverse=True)
for i in forgraph:
  if i[0]=='Блог' or i[0]=='компании' or i[0]=='в':
      forgraph.remove(i)
x3=[]
y3=[]
for i in forgraph:
  x3.append(i[0])
  y3.append(i[1])
#Для 4
b=[]
c=[]
for i in razn4['hubs']:
  b.append(i.split())
for j in b:
  for k in j:
    c.append(k)
f = dict()
for i in c:
  if i not in f:
    f['{}'.format(i)] = 1
  else:
    f['{}'.format(i)] += 1
forgraph=list(f.items())
forgraph.sort(key=lambda x:x[1], reverse=True)
for i in forgraph:
  if i[0]=='Блог' or i[0]=='компании' or i[0]=='в':
      forgraph.remove(i)
x4=[]
y4=[]
for i in forgraph:
  x4.append(i[0])
  y4.append(i[1])
#Для 5
b=[]
c=[]
for i in razn5['hubs']:
  b.append(i.split())
for j in b:
  for k in j:
    c.append(k)
f = dict()
for i in c:
  if i not in f:
    f['{}'.format(i)] = 1
  else:
    f['{}'.format(i)] += 1
forgraph=list(f.items())
forgraph.sort(key=lambda x:x[1], reverse=True)
for i in forgraph:
  if i[0]=='Блог' or i[0]=='компании' or i[0]=='в':
      forgraph.remove(i)
x5=[]
y5=[]
for i in forgraph:
  x5.append(i[0])
  y5.append(i[1])
#Для 6
b=[]
c=[]
for i in razn6['hubs']:
  b.append(i.split())
for j in b:
  for k in j:
    c.append(k)
f = dict()
for i in c:
  if i not in f:
    f['{}'.format(i)] = 1
  else:
    f['{}'.format(i)] += 1
forgraph=list(f.items())
forgraph.sort(key=lambda x:x[1], reverse=True)
for i in forgraph:
  if i[0]=='Блог' or i[0]=='компании' or i[0]=='в':
      forgraph.remove(i)
x6=[]
y6=[]
for i in forgraph:
  x6.append(i[0])
  y6.append(i[1])

# %% [markdown]
# ###Прикольные графички

# %%
fig, ax = plt.subplots(2,3,figsize=(50,25))
ax[0,0].plot(x1[:20], y1[:20])
ax[0,0].tick_params(labelrotation=90)
ax[0,0].set_title('Разница между 0.05 и 0.06')
ax[0,1].plot(x2[:20], y2[:20])
ax[0,1].tick_params(labelrotation=90)
ax[0,1].set_title('Разница между 0.06 и 0.07')
ax[0,2].plot(x3[:20], y3[:20])
ax[0,2].tick_params(labelrotation=90)
ax[0,2].set_title('Разница между 0.07 и 0.08')
ax[1,0].plot(x4[:20], y4[:20])
ax[1,0].tick_params(labelrotation=90)
ax[1,0].set_title('Разница между 0.08 и 0.09')
ax[1,1].plot(x5[:20], y5[:20])
ax[1,1].tick_params(labelrotation=90)
ax[1,1].set_title('Разница между 0.09 и 0.10')
ax[1,2].plot(x6[:20], y6[:20])
ax[1,2].tick_params(labelrotation=90)
ax[1,2].set_title('Разница между 0.10 и 0.11')
plt.xticks(rotation=90)
plt.show()

# %%
vseg = df.iloc[fint[0]].reset_index()

# %%
b=[]
c=[]
for i in vseg['hubs']:
  b.append(i.split())
for j in b:
  for k in j:
    c.append(k)
f = dict()
for i in c:
  if i not in f:
    f['{}'.format(i)] = 1
  else:
    f['{}'.format(i)] += 1
forgraph=list(f.items())
forgraph.sort(key=lambda x:x[1], reverse=True)
for i in forgraph:
  if i[0]=='Блог' or i[0]=='компании' or i[0]=='в' or i[0]=='под' or i[0]=='и':
      forgraph.remove(i)
forgraph = forgraph[1:]
x=[]
y=[]
for i in forgraph:
  x.append(i[0])
  y.append(i[1])
y=np.array(y)
fig, ax = plt.subplots(figsize=(10,5))
ax.plot(x[:20], y[:20],marker='*')
ax.tick_params(labelrotation=90)
ax.set_title('Всего при отборе 0.05')
plt.show()

# %%
b=[]
c=[]
for i in vseg['hubs']:
  b.append(i.split())
for j in b:
  for k in j:
    c.append(k)
f = dict()
for i in c:
  if i not in f:
    f['{}'.format(i)] = 1
  else:
    f['{}'.format(i)] += 1
forgraph=list(f.items())
forgraph.sort(key=lambda x:x[1], reverse=True)
for i in forgraph:
  if i[0]=='Блог' or i[0]=='компании' or i[0]=='в' or i[0]=='под' or i[0]=='и':
      forgraph.remove(i)
forgraph = forgraph[1:]
x=[]
y=[]
for i in forgraph:
  x.append(i[0])
  y.append(i[1])
y=np.array(y)
b1=[]
c1=[]
for i in df['hubs']:
  b1.append(i.split())
for j in b1:
  for k in j:
    c1.append(k)
f1 = dict()
for i in c1:
  if i not in f1:
    f1['{}'.format(i)] = 1
  else:
    f1['{}'.format(i)] += 1
yall=[]
for i in x[:50]:
  yall.append(f1[i])
yall= np.array(yall)
fig, ax = plt.subplots(figsize=(15,5))
ax.plot(x[:50], y[:50]/yall,marker='*')
ax.tick_params(labelrotation=90)
ax.set_title('Всего при отборе 0.05')
plt.show()
