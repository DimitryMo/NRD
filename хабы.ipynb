# %%
info = []

# %%
 ###руками меняй номер страницы со 2 по 11, для первой https://habr.com/ru/hubs/
  r = requests.get('https://habr.com/ru/hubs/page2/')
  soup = BeautifulSoup(r.text, 'html5lib')
  for tag in soup.find_all('a', class_="list-snippet__title-link"):
    info.append(tag.text)
    for t in soup.find_all('div', class_="list-snippet__tags"):
      info.append(t.text)

# %%
info
# Out:
# ['Управление продуктом',
#  'управление проектами, стартапы, управление продуктом, agile, product management, разработка, маркетинг, scrum, управление, аналитика',
#  'tesla, транспорт, электромобили, илон маск, автомобили, робомобили, spacex, автопилот, беспилотные автомобили, будущее',
#  'искусственный интеллект, машинное обучение, ии, нейронные сети, нейросети, ai, machine learning, роботы, google, нейросеть',
#  'космос, космонавтика, spacex, nasa, луна, марс, мкс, наса, роскосмос, спутники',
#  'reverse engineering, реверс-инжиниринг, reactos, обратная разработка, assembler, информационная безопасность, отладка, android, ida pro, nes',
#  'микроконтроллеры, stm32, arduino, fpga, программирование микроконтроллеров, iot, avr, плис, rtos, arm',
#  'google, поиск, яндекс, поисковые системы, seo, nigma, поисковые технологии, elasticsearch, нигма, машинное обучение',
# ...

# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd
import numpy as np
import re
